# %% [markdown]
# ## Clean NER data

# %%
def removeDuplicates(data,colName):
    data.sort_values(colName, inplace = True) 
  
    # making a bool series 
    bool_series = data[colName].duplicated(keep = False) 

    # bool series 
    bool_series 

    # passing NOT of bool series to see unique values only 
    data = data[~bool_series] 

    return data

# %%
import pandas as pd 
data = pd.read_csv("genre.csv") 
data['name']=data['name'].str.lower()
df=removeDuplicates(data,"name")
df.to_csv("cleanData/Genre.csv",index=False)
# Out:
#            name
# count        63
# unique       63
# top     video
# freq          1

# %% [markdown]
# ## Convert NER Data to Spacy format
#
# Training data format is :
#  [('what is the price of polo?', {'entities': [(21, 25, 'PrdName')]}), ...]

# %%
import spacy
import random
from spacy import displacy

# %%
genra_data = pd.read_csv("cleanData/Genre.csv") 
style_data = pd.read_csv("cleanData/Style.csv") 
medium_data = pd.read_csv("cleanData/Medium.csv") 
genra_data['lable']="genra"
style_data['lable']="style"
medium_data['lable']="medium"
newLb=pd.concat([genra_data, style_data,medium_data], ignore_index=True)
newLb['name']=newLb['name'].str.strip()

# %%
TRAIN_DATA = []
for index, row in newLb.iterrows(): 
    name=row["name"]
    temp=(name,{'entities': [(0, len(name), row["lable"])]}) 
    TRAIN_DATA.append(temp)
TRAIN_DATA
# Out:
# [('abstract', {'entities': [(0, 8, 'genra')]}),
#  ('advertisement', {'entities': [(0, 13, 'genra')]}),
#  ('allegorical painting', {'entities': [(0, 20, 'genra')]}),
#  ('animal painting', {'entities': [(0, 15, 'genra')]}),
#  ('animation', {'entities': [(0, 9, 'genra')]}),
#  ('architecture', {'entities': [(0, 12, 'genra')]}),
#  ("artist's book", {'entities': [(0, 13, 'genra')]}),
#  ('battle painting', {'entities': [(0, 15, 'genra')]}),
#  ('bijinga', {'entities': [(0, 7, 'genra')]}),
#  ('bird-and-flower painting', {'entities': [(0, 24, 'genra')]}),
#  ('calligraphy', {'entities': [(0, 11, 'genra')]}),
#  ('capriccio', {'entities': [(0, 9, 'genra')]}),
#  ('caricature', {'entities': [(0, 10, 'genra')]}),
#  ('cityscape', {'entities': [(0, 9, 'genra')]}),
#  ('cloudscape', {'entities': [(0, 10, 'genra')]}),
#  ('design', {'entities': [(0, 6, 'genra')]}),
#  ('figurative', {'entities': [(0, 10, 'genra')]}),
#  ('flower painting', {'entities': [(0, 15, 'genra')]}),
#  ('genre painting', {'entities': [(0, 14, 'genra')]}),
#  ('graffiti', {'entities': [(0, 8, 'genra')]}),
#  ('history painting', {'entities': [(0, 16, 'genra')]}),
#  ('illustration', {'entities': [(0, 12, 'genra')]}),
#  ('installation', {'entities': [(0, 12, 'genra')]}),
#  ('interior', {'entities': [(0, 8, 'genra')]}),
#  ('jewelry', {'entities': [(0, 7, 'genra')]}),
#  ('landscape', {'entities': [(0, 9, 'genra')]}),
#  ('literary painting', {'entities': [(0, 17, 'genra')]}),
#  ('marina', {'entities': [(0, 6, 'genra')]}),
#  ('miniature', {'entities': [(0, 9, 'genra')]}),
#  ('mobile', {'entities': [(0, 6, 'genra')]}),
#  ('mosaic', {'entities': [(0, 6, 'genra')]}),
#  ('mural', {'entities': [(0, 5, 'genra')]}),
#  ('mythological painting', {'entities': [(0, 21, 'genra')]}),
#  ('nu', {'entities': [(0, 2, 'genra')]}),
#  ('nude painting', {'entities': [(0, 13, 'genra')]}),
#  ('ornament', {'entities': [(0, 8, 'genra')]}),
#  ('panorama', {'entities': [(0, 8, 'genra')]}),
#  ('pastorale', {'entities': [(0, 9, 'genra')]}),
#  ('performance', {'entities': [(0, 11, 'genra')]}),
#  ('photo', {'entities': [(0, 5, 'genra')]}),
#  ('pin-up', {'entities': [(0, 6, 'genra')]}),
#  ('portrait', {'entities': [(0, 8, 'genra')]}),
#  ('poster', {'entities': [(0, 6, 'genra')]}),
#  ('quadratura', {'entities': [(0, 10, 'genra')]}),
#  ('religious painting', {'entities': [(0, 18, 'genra')]}),
#  ('sculpture', {'entities': [(0, 9, 'genra')]}),
#  ('self-portrait', {'entities': [(0, 13, 'genra')]}),
#  ('shan shui', {'entities': [(0, 9, 'genra')]}),
#  ('sketch and study', {'entities': [(0, 16, 'genra')]}),
#  ('stabile', {'entities': [(0, 7, 'genra')]}),
#  ('still life', {'entities': [(0, 10, 'genra')]}),
#  ('symbolic painting', {'entities': [(0, 17, 'genra')]}),
#  ('tapestry', {'entities': [(0, 8, 'genra')]}),
#  ('tessellation', {'entities': [(0, 12, 'genra')]}),
#  ("trompe-l'œil", {'entities': [(0, 12, 'genra')]}),
#  ('tronie', {'entities': [(0, 6, 'genra')]}),
#  ('urushi-e', {'entities': [(0, 8, 'genra')]}),
#  ('utensil', {'entities': [(0, 7, 'genra')]}),
#  ('vanitas', {'entities': [(0, 7, 'genra')]}),
#  ('veduta', {'entities': [(0, 6, 'genra')]}),
#  ('video', {'entities': [(0, 5, 'genra')]}),
#  ('wildlife painting', {'entities': [(0, 17, 'genra')]}),
#  ('yakusha-e', {'entities': [(0, 9, 'genra')]}),
#  ('2nd intermediate period', {'entities': [(0, 23, 'style')]}),
#  ('3rd intermediate period', {'entities': [(0, 23, 'style')]}),
#  ('abstract art', {'entities': [(0, 12, 'style')]}),
#  ('abstract expressionism', {'entities': [(0, 22, 'style')]}),
#  ('academicism', {'entities': [(0, 11, 'style')]}),
#  ('action painting', {'entities': [(0, 15, 'style')]}),
#  ('amarna', {'entities': [(0, 6, 'style')]}),
#  ('american realism', {'entities': [(0, 16, 'style')]}),
#  ('anachronism', {'entities': [(0, 11, 'style')]}),
#  ('analytical cubism', {'entities': [(0, 17, 'style')]}),
#  ('analytical realism', {'entities': [(0, 18, 'style')]}),
#  ('ancient egyptian art', {'entities': [(0, 20, 'style')]}),
#  ('ancient greek art', {'entities': [(0, 17, 'style')]}),
#  ('archaic', {'entities': [(0, 7, 'style')]}),
#  ('art brut', {'entities': [(0, 8, 'style')]}),
#  ('art deco', {'entities': [(0, 8, 'style')]}),
#  ('art informel', {'entities': [(0, 12, 'style')]}),
#  ('art nouveau', {'entities': [(0, 11, 'style')]}),
#  ('art singulier', {'entities': [(0, 13, 'style')]}),
#  ('automatic painting', {'entities': [(0, 18, 'style')]}),
#  ('baroque', {'entities': [(0, 7, 'style')]}),
#  ('biedermeier', {'entities': [(0, 11, 'style')]}),
#  ('bunjinga', {'entities': [(0, 8, 'style')]}),
#  ('byzantine', {'entities': [(0, 9, 'style')]}),
#  ('cartographic art', {'entities': [(0, 16, 'style')]}),
#  ('chinese art', {'entities': [(0, 11, 'style')]}),
#  ('classical', {'entities': [(0, 9, 'style')]}),
#  ('classicism', {'entities': [(0, 10, 'style')]}),
#  ('cloisonnism', {'entities': [(0, 11, 'style')]}),
#  ('color field painting', {'entities': [(0, 20, 'style')]}),
#  ('conceptual art', {'entities': [(0, 14, 'style')]}),
#  ('concretism', {'entities': [(0, 10, 'style')]}),
#  ('constructivism', {'entities': [(0, 14, 'style')]}),
#  ('contemporary', {'entities': [(0, 12, 'style')]}),
#  ('contemporary art', {'entities': [(0, 16, 'style')]}),
#  ('contemporary realism', {'entities': [(0, 20, 'style')]}),
#  ('costumbrismo', {'entities': [(0, 12, 'style')]}),
#  ('cubism', {'entities': [(0, 6, 'style')]}),
#  ('cubo-expressionism', {'entities': [(0, 18, 'style')]}),
#  ('cubo-futurism', {'entities': [(0, 13, 'style')]}),
#  ('cyber art', {'entities': [(0, 9, 'style')]}),
#  ('dada', {'entities': [(0, 4, 'style')]}),
#  ('digital art', {'entities': [(0, 11, 'style')]}),
#  ('divisionism', {'entities': [(0, 11, 'style')]}),
#  ('early byzantine', {'entities': [(0, 15, 'style')]}),
#  ('early christian', {'entities': [(0, 15, 'style')]}),
#  ('early dynastic', {'entities': [(0, 14, 'style')]}),
#  ('early renaissance', {'entities': [(0, 17, 'style')]}),
#  ('environmental land art', {'entities': [(0, 22, 'style')]}),
#  ('excessivism', {'entities': [(0, 11, 'style')]}),
#  ('existential art', {'entities': [(0, 15, 'style')]}),
#  ('expressionism', {'entities': [(0, 13, 'style')]}),
#  ('fantastic realism', {'entities': [(0, 17, 'style')]}),
#  ('fantasy art', {'entities': [(0, 11, 'style')]}),
#  ('fauvism', {'entities': [(0, 7, 'style')]}),
#  ('feminist art', {'entities': [(0, 12, 'style')]}),
#  ('fiber art', {'entities': [(0, 9, 'style')]}),
#  ('figurative expressionism', {'entities': [(0, 24, 'style')]}),
#  ('folk art', {'entities': [(0, 8, 'style')]}),
#  ('futurism', {'entities': [(0, 8, 'style')]}),
#  ('geometric', {'entities': [(0, 9, 'style')]}),
#  ('gongbi', {'entities': [(0, 6, 'style')]}),
#  ('gothic', {'entities': [(0, 6, 'style')]}),
#  ('graffiti art', {'entities': [(0, 12, 'style')]}),
#  ('hard edge painting', {'entities': [(0, 18, 'style')]}),
#  ('hellenistic', {'entities': [(0, 11, 'style')]}),
#  ('high renaissance', {'entities': [(0, 16, 'style')]}),
#  ('hyper-mannerism', {'entities': [(0, 15, 'style')]}),
#  ('hyper-realism', {'entities': [(0, 13, 'style')]}),
#  ('ilkhanid', {'entities': [(0, 8, 'style')]}),
#  ('impressionism', {'entities': [(0, 13, 'style')]}),
#  ('indian space painting', {'entities': [(0, 21, 'style')]}),
#  ('ink and wash painting', {'entities': [(0, 21, 'style')]}),
#  ('international gothic', {'entities': [(0, 20, 'style')]}),
#  ('intimism', {'entities': [(0, 8, 'style')]}),
#  ('islamic art', {'entities': [(0, 11, 'style')]}),
#  ('japanese art', {'entities': [(0, 12, 'style')]}),
#  ('japonism', {'entities': [(0, 8, 'style')]}),
#  ('joseon dynasty', {'entities': [(0, 14, 'style')]}),
#  ('junk art', {'entities': [(0, 8, 'style')]}),
#  ('kanō school style', {'entities': [(0, 17, 'style')]}),
#  ('kinetic art', {'entities': [(0, 11, 'style')]}),
#  ('kitsch', {'entities': [(0, 6, 'style')]}),
#  ('korean art', {'entities': [(0, 10, 'style')]}),
#  ('land art', {'entities': [(0, 8, 'style')]}),
#  ('late byzantine/palaeologan renaissance', {'entities': [(0, 38, 'style')]}),
#  ('late period', {'entities': [(0, 11, 'style')]}),
#  ('late renaissance', {'entities': [(0, 16, 'style')]}),
#  ('lettrism', {'entities': [(0, 8, 'style')]}),
#  ('light and space', {'entities': [(0, 15, 'style')]}),
#  ('lowbrow art', {'entities': [(0, 11, 'style')]}),
#  ('luminism', {'entities': [(0, 8, 'style')]}),
#  ('lyrical abstraction', {'entities': [(0, 19, 'style')]}),
#  ('macedonian renaissance', {'entities': [(0, 22, 'style')]}),
#  ('magic realism', {'entities': [(0, 13, 'style')]}),
#  ('mail art', {'entities': [(0, 8, 'style')]}),
#  ('mannerism', {'entities': [(0, 9, 'style')]}),
#  ('maximalism', {'entities': [(0, 10, 'style')]}),
#  ('mechanistic cubism', {'entities': [(0, 18, 'style')]}),
#  ('medieval art', {'entities': [(0, 12, 'style')]}),
#  ('metaphysical art', {'entities': [(0, 16, 'style')]}),
#  ('middle byzantine', {'entities': [(0, 16, 'style')]}),
#  ('middle kingdom', {'entities': [(0, 14, 'style')]}),
#  ('minimalism', {'entities': [(0, 10, 'style')]}),
#  ('miserablism', {'entities': [(0, 11, 'style')]}),
#  ('modern', {'entities': [(0, 6, 'style')]}),
#  ('modern art', {'entities': [(0, 10, 'style')]}),
#  ('modernismo', {'entities': [(0, 10, 'style')]}),
#  ('mosan art', {'entities': [(0, 9, 'style')]}),
#  ('mozarabic', {'entities': [(0, 9, 'style')]}),
#  ('mughal', {'entities': [(0, 6, 'style')]}),
#  ('muralism', {'entities': [(0, 8, 'style')]}),
#  ('nanga', {'entities': [(0, 5, 'style')]}),
#  ('nas-taliq', {'entities': [(0, 9, 'style')]}),
#  ('native art', {'entities': [(0, 10, 'style')]}),
#  ('naturalism', {'entities': [(0, 10, 'style')]}),
#  ('naïve art', {'entities': [(0, 9, 'style')]}),
#  ('neo-baroque', {'entities': [(0, 11, 'style')]}),
#  ('neo-byzantine', {'entities': [(0, 13, 'style')]}),
#  ('neo-concretism', {'entities': [(0, 14, 'style')]}),
#  ('neo-dada', {'entities': [(0, 8, 'style')]}),
#  ('neo-expressionism', {'entities': [(0, 17, 'style')]}),
#  ('neo-figurative art', {'entities': [(0, 18, 'style')]}),
#  ('neo-geo', {'entities': [(0, 7, 'style')]}),
#  ('neo-minimalism', {'entities': [(0, 14, 'style')]}),
#  ('neo-orthodoxism', {'entities': [(0, 15, 'style')]}),
#  ('neo-pop art', {'entities': [(0, 11, 'style')]}),
#  ('neo-rococo', {'entities': [(0, 10, 'style')]}),
#  ('neo-romanticism', {'entities': [(0, 15, 'style')]}),
#  ('neo-suprematism', {'entities': [(0, 15, 'style')]}),
#  ('neoclassicism', {'entities': [(0, 13, 'style')]}),
#  ('neoplasticism', {'entities': [(0, 13, 'style')]}),
#  ('new casualism', {'entities': [(0, 13, 'style')]}),
#  ('new european painting', {'entities': [(0, 21, 'style')]}),
#  ('new kingdom', {'entities': [(0, 11, 'style')]}),
#  ('new medievialism', {'entities': [(0, 16, 'style')]}),
#  ('new realism', {'entities': [(0, 11, 'style')]}),
#  ('nihonga', {'entities': [(0, 7, 'style')]}),
#  ('northern renaissance', {'entities': [(0, 20, 'style')]}),
#  ('nouveau réalisme', {'entities': [(0, 16, 'style')]}),
#  ('op art', {'entities': [(0, 6, 'style')]}),
#  ('orientalism', {'entities': [(0, 11, 'style')]}),
#  ('orphism', {'entities': [(0, 7, 'style')]}),
#  ('ottoman period', {'entities': [(0, 14, 'style')]}),
#  ('outsider art', {'entities': [(0, 12, 'style')]}),
#  ('p&d', {'entities': [(0, 3, 'style')]}),
#  ('pattern and decoration', {'entities': [(0, 22, 'style')]}),
#  ('perceptism', {'entities': [(0, 10, 'style')]}),
#  ('performance art', {'entities': [(0, 15, 'style')]}),
#  ('photorealism', {'entities': [(0, 12, 'style')]}),
#  ('pictorialism', {'entities': [(0, 12, 'style')]}),
#  ('pointillism', {'entities': [(0, 11, 'style')]}),
#  ('pop art', {'entities': [(0, 7, 'style')]}),
#  ('post renaissance art', {'entities': [(0, 20, 'style')]}),
#  ('post-classic', {'entities': [(0, 12, 'style')]}),
#  ('post-impressionism', {'entities': [(0, 18, 'style')]}),
#  ('post-minimalism', {'entities': [(0, 15, 'style')]}),
#  ('post-painterly abstraction', {'entities': [(0, 26, 'style')]}),
#  ('poster art realism', {'entities': [(0, 18, 'style')]}),
#  ('pre-columbian art', {'entities': [(0, 17, 'style')]}),
#  ('precisionism', {'entities': [(0, 12, 'style')]}),
#  ('primitivism', {'entities': [(0, 11, 'style')]}),
#  ('proto renaissance', {'entities': [(0, 17, 'style')]}),
#  ('ptolemaic', {'entities': [(0, 9, 'style')]}),
#  ('purism', {'entities': [(0, 6, 'style')]}),
#  ('rayonism', {'entities': [(0, 8, 'style')]}),
#  ('realism', {'entities': [(0, 7, 'style')]}),
#  ('regionalism', {'entities': [(0, 11, 'style')]}),
#  ('renaissance', {'entities': [(0, 11, 'style')]}),
#  ('renaissance art', {'entities': [(0, 15, 'style')]}),
#  ('rococo', {'entities': [(0, 6, 'style')]}),
#  ('romanesque', {'entities': [(0, 10, 'style')]}),
#  ('romanticism', {'entities': [(0, 11, 'style')]}),
#  ('safavid period', {'entities': [(0, 14, 'style')]}),
#  ('severe style', {'entities': [(0, 12, 'style')]}),
#  ('shin-hanga', {'entities': [(0, 10, 'style')]}),
#  ('site-specific art', {'entities': [(0, 17, 'style')]}),
#  ('sky art', {'entities': [(0, 7, 'style')]}),
#  ('social realism', {'entities': [(0, 14, 'style')]}),
#  ('socialist realism', {'entities': [(0, 17, 'style')]}),
#  ('sots art', {'entities': [(0, 8, 'style')]}),
#  ('spatialism', {'entities': [(0, 10, 'style')]}),
#  ('spectralism', {'entities': [(0, 11, 'style')]}),
#  ('street art', {'entities': [(0, 10, 'style')]}),
#  ('street photography', {'entities': [(0, 18, 'style')]}),
#  ('stuckism', {'entities': [(0, 8, 'style')]}),
#  ('suiboku-ga', {'entities': [(0, 10, 'style')]}),
#  ('sumi-e', {'entities': [(0, 6, 'style')]}),
#  ('superflat', {'entities': [(0, 9, 'style')]}),
#  ('suprematism', {'entities': [(0, 11, 'style')]}),
#  ('surrealism', {'entities': [(0, 10, 'style')]}),
#  ('symbiotic art', {'entities': [(0, 13, 'style')]}),
#  ('symbolism', {'entities': [(0, 9, 'style')]}),
#  ('synchromism', {'entities': [(0, 11, 'style')]}),
#  ('synthetic cubism', {'entities': [(0, 16, 'style')]}),
#  ('synthetism', {'entities': [(0, 10, 'style')]}),
#  ('sōsaku hanga', {'entities': [(0, 12, 'style')]}),
#  ('tachisme', {'entities': [(0, 8, 'style')]}),
#  ('tenebrism', {'entities': [(0, 9, 'style')]}),
#  ('timurid period', {'entities': [(0, 14, 'style')]}),
#  ('tonalism', {'entities': [(0, 8, 'style')]}),
#  ('transautomatism', {'entities': [(0, 15, 'style')]}),
#  ('transavantgarde', {'entities': [(0, 15, 'style')]}),
#  ('tubism', {'entities': [(0, 6, 'style')]}),
#  ('ukiyo-e', {'entities': [(0, 7, 'style')]}),
#  ('verism', {'entities': [(0, 6, 'style')]}),
#  ('viking art', {'entities': [(0, 10, 'style')]}),
#  ('yamato-e', {'entities': [(0, 8, 'style')]}),
#  ('yoruba', {'entities': [(0, 6, 'style')]}),
#  ('zen', {'entities': [(0, 3, 'style')]}),
#  ('acids to create a patina', {'entities': [(0, 24, 'medium')]}),
#  ('action painting', {'entities': [(0, 15, 'medium')]}),
#  ('adhesives', {'entities': [(0, 9, 'medium')]}),
#  ('aquatint', {'entities': [(0, 8, 'medium')]}),
#  ('architectural structures', {'entities': [(0, 24, 'medium')]}),
#  ('ballpoint pen', {'entities': [(0, 13, 'medium')]}),
#  ('batik', {'entities': [(0, 5, 'medium')]}),
#  ('beads', {'entities': [(0, 5, 'medium')]}),
#  ('black palm', {'entities': [(0, 10, 'medium')]}),
#  ('blacklight paint', {'entities': [(0, 16, 'medium')]}),
#  ('bone carving', {'entities': [(0, 12, 'medium')]}),
#  ('bone china', {'entities': [(0, 10, 'medium')]}),
#  ('brick', {'entities': [(0, 5, 'medium')]}),
#  ('bristle brush', {'entities': [(0, 13, 'medium')]}),
#  ('bronze', {'entities': [(0, 6, 'medium')]}),
#  ('brush', {'entities': [(0, 5, 'medium')]}),
#  ('cardboard', {'entities': [(0, 9, 'medium')]}),
#  ('chalk', {'entities': [(0, 5, 'medium')]}),
#  ('chisel and hammer', {'entities': [(0, 17, 'medium')]}),
#  ('clamp or aims', {'entities': [(0, 13, 'medium')]}),
#  ('cob', {'entities': [(0, 3, 'medium')]}),
#  ('coconut juice', {'entities': [(0, 13, 'medium')]}),
#  ('coffee', {'entities': [(0, 6, 'medium')]}),
#  ('colored pencil', {'entities': [(0, 14, 'medium')]}),
#  ('computer printing', {'entities': [(0, 17, 'medium')]}),
#  ('concrete', {'entities': [(0, 8, 'medium')]}),
#  ('corrosive', {'entities': [(0, 9, 'medium')]}),
#  ('corrugated fiberboard', {'entities': [(0, 21, 'medium')]}),
#  ('cotton', {'entities': [(0, 6, 'medium')]}),
#  ('digital image sensor', {'entities': [(0, 20, 'medium')]}),
#  ('digital painting', {'entities': [(0, 16, 'medium')]}),
#  ('digital word processor and internet websites',
#   {'entities': [(0, 44, 'medium')]}),
#  ('dye-sublimation printer', {'entities': [(0, 23, 'medium')]}),
#  ('edible material', {'entities': [(0, 15, 'medium')]}),
#  ('embossing', {'entities': [(0, 9, 'medium')]}),
#  ('encaustic paint', {'entities': [(0, 15, 'medium')]}),
#  ('engraving', {'entities': [(0, 9, 'medium')]}),
#  ('etching', {'entities': [(0, 7, 'medium')]}),
#  ('fabric', {'entities': [(0, 6, 'medium')]}),
#  ('fiber', {'entities': [(0, 5, 'medium')]}),
#  ('flax', {'entities': [(0, 4, 'medium')]}),
#  ('floral design', {'entities': [(0, 13, 'medium')]}),
#  ('foil', {'entities': [(0, 4, 'medium')]}),
#  ('found objects', {'entities': [(0, 13, 'medium')]}),
#  ('fountain pen', {'entities': [(0, 12, 'medium')]}),
#  ('garlic', {'entities': [(0, 6, 'medium')]}),
#  ('gel pen', {'entities': [(0, 7, 'medium')]}),
#  ('gemstones', {'entities': [(0, 9, 'medium')]}),
#  ('gesso', {'entities': [(0, 5, 'medium')]}),
#  ('giclée printing', {'entities': [(0, 15, 'medium')]}),
#  ('glue and other adhesives', {'entities': [(0, 24, 'medium')]}),
#  ('gold', {'entities': [(0, 4, 'medium')]}),
#  ('granite', {'entities': [(0, 7, 'medium')]}),
#  ('graphite', {'entities': [(0, 8, 'medium')]}),
#  ('hammer gold mallet', {'entities': [(0, 18, 'medium')]}),
#  ('human finger', {'entities': [(0, 12, 'medium')]}),
#  ('human hair and blood', {'entities': [(0, 20, 'medium')]}),
#  ('ice', {'entities': [(0, 3, 'medium')]}),
#  ('image projector', {'entities': [(0, 15, 'medium')]}),
#  ('ink', {'entities': [(0, 3, 'medium')]}),
#  ('ink wash', {'entities': [(0, 8, 'medium')]}),
#  ('inkjet printer', {'entities': [(0, 14, 'medium')]}),
#  ('intaglio', {'entities': [(0, 8, 'medium')]}),
#  ('ivory', {'entities': [(0, 5, 'medium')]}),
#  ('kiln for heating ceramics and metals', {'entities': [(0, 36, 'medium')]}),
#  ('knife', {'entities': [(0, 5, 'medium')]}),
#  ('knitting', {'entities': [(0, 8, 'medium')]}),
#  ('laser printer', {'entities': [(0, 13, 'medium')]}),
#  ('latex paint', {'entities': [(0, 11, 'medium')]}),
#  ('letterpress', {'entities': [(0, 11, 'medium')]}),
#  ('letterpress printing and computer printing',
#   {'entities': [(0, 42, 'medium')]}),
#  ('light', {'entities': [(0, 5, 'medium')]}),
#  ('lithography', {'entities': [(0, 11, 'medium')]}),
#  ('macramé', {'entities': [(0, 7, 'medium')]}),
#  ('magna paint', {'entities': [(0, 11, 'medium')]}),
#  ('marble', {'entities': [(0, 6, 'medium')]}),
#  ('marker pen', {'entities': [(0, 10, 'medium')]}),
#  ('metalcut', {'entities': [(0, 8, 'medium')]}),
#  ('mezzotint', {'entities': [(0, 9, 'medium')]}),
#  ('modern pneumatic', {'entities': [(0, 16, 'medium')]}),
#  ('moku hanga', {'entities': [(0, 10, 'medium')]}),
#  ('monotype', {'entities': [(0, 8, 'medium')]}),
#  ('mortar', {'entities': [(0, 6, 'medium')]}),
#  ('mosaic', {'entities': [(0, 6, 'medium')]}),
#  ('mud', {'entities': [(0, 3, 'medium')]}),
#  ('nib', {'entities': [(0, 3, 'medium')]}),
#  ('offset printing', {'entities': [(0, 15, 'medium')]}),
#  ('onion', {'entities': [(0, 5, 'medium')]}),
#  ('paint roller gold paint pad', {'entities': [(0, 27, 'medium')]}),
#  ('palette knife', {'entities': [(0, 13, 'medium')]}),
#  ('paper mache', {'entities': [(0, 11, 'medium')]}),
#  ('pastel', {'entities': [(0, 6, 'medium')]}),
#  ('photographic film', {'entities': [(0, 17, 'medium')]}),
#  ('photographic printing', {'entities': [(0, 21, 'medium')]}),
#  ('planographic printing', {'entities': [(0, 21, 'medium')]}),
#  ('plastic explosive', {'entities': [(0, 17, 'medium')]}),
#  ('pliers', {'entities': [(0, 6, 'medium')]}),
#  ('polychrome', {'entities': [(0, 10, 'medium')]}),
#  ('porcelain', {'entities': [(0, 9, 'medium')]}),
#  ('potassium dichromate', {'entities': [(0, 20, 'medium')]}),
#  ('potassium ferricyanide and ferric ammonium citrate',
#   {'entities': [(0, 50, 'medium')]}),
#  ('pottery', {'entities': [(0, 7, 'medium')]}),
#  ('potter’s wheel', {'entities': [(0, 14, 'medium')]}),
#  ('pounce art', {'entities': [(0, 10, 'medium')]}),
#  ('power tools', {'entities': [(0, 11, 'medium')]}),
#  ('primer', {'entities': [(0, 6, 'medium')]}),
#  ('printing press', {'entities': [(0, 14, 'medium')]}),
#  ('printmaking', {'entities': [(0, 11, 'medium')]}),
#  ('quill', {'entities': [(0, 5, 'medium')]}),
#  ('relief etching', {'entities': [(0, 14, 'medium')]}),
#  ('relief printing', {'entities': [(0, 15, 'medium')]}),
#  ('rock', {'entities': [(0, 4, 'medium')]}),
#  ('ruled paper', {'entities': [(0, 11, 'medium')]}),
#  ('rust', {'entities': [(0, 4, 'medium')]}),
#  ('sandpaper', {'entities': [(0, 9, 'medium')]}),
#  ('saw', {'entities': [(0, 3, 'medium')]}),
#  ('scraper', {'entities': [(0, 7, 'medium')]}),
#  ('scratchboard', {'entities': [(0, 12, 'medium')]}),
#  ('screen-printing', {'entities': [(0, 15, 'medium')]}),
#  ('silk', {'entities': [(0, 4, 'medium')]}),
#  ('silver', {'entities': [(0, 6, 'medium')]}),
#  ('silver nitrate', {'entities': [(0, 14, 'medium')]}),
#  ('snips', {'entities': [(0, 5, 'medium')]}),
#  ('soil', {'entities': [(0, 4, 'medium')]}),
#  ('solar from sun', {'entities': [(0, 14, 'medium')]}),
#  ('solid ink printer', {'entities': [(0, 17, 'medium')]}),
#  ('soy sauce', {'entities': [(0, 9, 'medium')]}),
#  ('sponge', {'entities': [(0, 6, 'medium')]}),
#  ('staple wire', {'entities': [(0, 11, 'medium')]}),
#  ('stencil', {'entities': [(0, 7, 'medium')]}),
#  ('stick', {'entities': [(0, 5, 'medium')]}),
#  ('styrofoam', {'entities': [(0, 9, 'medium')]}),
#  ('synthetic resin', {'entities': [(0, 15, 'medium')]}),
#  ('tale', {'entities': [(0, 4, 'medium')]}),
#  ('technical pen', {'entities': [(0, 13, 'medium')]}),
#  ('tempera', {'entities': [(0, 7, 'medium')]}),
#  ('tempera or poster paint', {'entities': [(0, 23, 'medium')]}),
#  ('terracotta', {'entities': [(0, 10, 'medium')]}),
#  ('textile', {'entities': [(0, 7, 'medium')]}),
#  ('thermal printer', {'entities': [(0, 15, 'medium')]}),
#  ('timber', {'entities': [(0, 6, 'medium')]}),
#  ('tomato', {'entities': [(0, 6, 'medium')]}),
#  ('tuba', {'entities': [(0, 4, 'medium')]}),
#  ('vegetation', {'entities': [(0, 10, 'medium')]}),
#  ('vinyl paint', {'entities': [(0, 11, 'medium')]}),
#  ('vitreous enamel', {'entities': [(0, 15, 'medium')]}),
#  ('wall', {'entities': [(0, 4, 'medium')]}),
#  ('walls', {'entities': [(0, 5, 'medium')]}),
#  ('water', {'entities': [(0, 5, 'medium')]}),
#  ('weaving', {'entities': [(0, 7, 'medium')]}),
#  ('welding and cutting torch', {'entities': [(0, 25, 'medium')]}),
#  ('wire', {'entities': [(0, 4, 'medium')]}),
#  ('wirecutter', {'entities': [(0, 10, 'medium')]}),
#  ('wood engraving', {'entities': [(0, 14, 'medium')]}),
#  ('woodblock printing', {'entities': [(0, 18, 'medium')]}),
#  ('woodcut', {'entities': [(0, 7, 'medium')]}),
#  ('wool', {'entities': [(0, 4, 'medium')]}),
#  ('yarn', {'entities': [(0, 4, 'medium')]})]

# %% [markdown]
# ## Train Spacy Model

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.load('en_core_web_sm')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
    else:
        ner = nlp.get_pipe('ner')
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
    return nlp

# %%
prdnlp = train_spacy(TRAIN_DATA, 20)

# Save our trained Model
modelfile = input("Enter your Model Name: ")
prdnlp.to_disk(modelfile)
# Out:
# Statring iteration 0
# {'ner': 568.0723570561408}
# Statring iteration 1
# {'ner': 464.95748757173163}
# Statring iteration 2
# {'ner': 434.45754296321775}
# Statring iteration 3
# {'ner': 384.0656252154281}
# Statring iteration 4
# {'ner': 353.78662708248163}
# Statring iteration 5
# {'ner': 314.8090607273916}
# Statring iteration 6
# {'ner': 324.86414690081506}
# Statring iteration 7
# {'ner': 313.91948017633007}
# Statring iteration 8
# {'ner': 327.011448704648}
# Statring iteration 9
# {'ner': 298.8379854843043}
# Statring iteration 10
# {'ner': 301.0056355236438}
# Statring iteration 11
# {'ner': 318.87600132926025}
# Statring iteration 12
# {'ner': 328.3235500817014}
# Statring iteration 13
# {'ner': 317.2902033575198}
# Statring iteration 14
# {'ner': 310.44941263615294}
# Statring iteration 15
# {'ner': 305.31569095913767}
# Statring iteration 16
# {'ner': 323.56686644447353}
# Statring iteration 17
# {'ner': 286.5402217668015}
# Statring iteration 18
# {'ner': 261.300319013712}
# Statring iteration 19
# {'ner': 342.0833404644066}
# Enter your Model Name: m2

# %% [markdown]
# ## Test the new Model

# %%
nlp = spacy.load("m2")
text = """But Google is starting from behind. The company made a late push into hardware, and Apple’s Siri, available on iPhones, and Amazon’s Alexa software, which runs on its Echo and Dot devices, have clear leads in consumer adoption."""  
doc = nlp(text) 
displacy.render(doc, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     But Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">style</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     is starting from behind.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The company made a late push into hardware, and Apple’s Siri, available on iPhones, and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon’s Alexa software, which runs on its Echo and Dot devices, have clear leads in consumer adoption.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
# </div></span>

# %%
import requests
import json

url="http://mec402.boisestate.edu/cgi-bin/assetSources/museums.py?q=lady&name=met&p=5&ps=1&type=1"
test_data = requests.get(url).json()
text=""
dd=test_data["data"][0]
# for d in dd:
#     text=text+str(dd[d])+"\n"
    
text=json.dumps(test_data)

doc = nlp(text.lower()) 
displacy.render(doc, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     {&quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">genra</span>
# </mark>
# data&quot;: [{&quot;openpipe_canonical_id&quot;: [197504], &quot;openpipe_canonical_title&quot;: [&quot;lady&quot;], &quot;openpipe_canonical_source&quot;: [&quot;met&quot;], &quot;openpipe_canonical_largeimage&quot;: [&quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     https://images.metmuseum.org/crdimages/es/original/dp-1135-010.jpg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">genra</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;], &quot;openpipe_canonical_largeimagedimensions&quot;: [&quot;3200,4000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">genra</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">genra</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;openpipe_canonical_smallimage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
# &quot;:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     [&quot;https://images.metmuseum.org/crdimages/es/web-large/dp-1135-010.jpg&quot;], &quot;openpipe_canonical_smallimagedimensions&quot;: [&quot;500,625&quot;], &quot;openpipe_canonical_artist&quot;: [&quot;thomas whieldon factory, stoke-on-trent, fenton vivian, staffordshire&quot;], &quot;openpipe_canonical_culture&quot;: [&quot;&quot;], &quot;openpipe_canonical_classification&quot;: [&quot;ceramics-pottery&quot;], &quot;openpipe_canonical_genre&quot;: [&quot;art-fi&quot;], &quot;openpipe_canonical_medium&quot;: [&quot;openpipe pixels&quot;], &quot;openpipe_canonical_nation&quot;: [&quot;&quot;], &quot;openpipe_canonical_city&quot;: [&quot;&quot;], &quot;openpipe_canonical_tags&quot;: [{&quot;term&quot;: &quot;sculpture&quot;, &quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aat_url&quot;: &quot;http://vocab.getty.edu/page/aat/300047090&quot;}, {&quot;term&quot;: &quot;women&quot;, &quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aat_url&quot;: &quot;http://vocab.getty.edu/page/aat/300025943&quot;}], &quot;openpipe_canonical_fullimage&quot;: [&quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     http://mec402.boisestate.edu/assets/largeimage.jpg&quot;]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     , &quot;openpipe_canonical_fullimagedimensions&quot;: [&quot;4000,3000&quot;],
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#  &quot;openpipe_canonical_date&quot;: [&quot;ce 1740 jan
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     01 00:00:00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">genra</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;, &quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">style</span>
# </mark>
# ce
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1750 jan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">style</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     01 00:00:00&quot;], &quot;openpipe_canonical_firstdate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">style</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     &quot;: [&quot;ce 1740 jan 01 00:00:00&quot;]
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
# , &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     openpipe_canonical_lastdate&quot;:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     [&quot;ce 1750 jan 01 00:00:00&quot;], &quot;asdf&quot;: [null],
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">medium</span>
# </mark>
#  &quot;objectid&quot;: 197504, &quot;ishighlight&quot;: false, &quot;accessionnumber&quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     : &quot;34.165.28
#     <span style="font-size: 0.8em; font-weight: bold; li
